# %% [markdown]
# # Swiss Labour-Market Break-Even Rates
#
# This notebook is a placeholder for the first project pass.
#
# Suggested early tasks:
# - map Swiss data sources for unemployment, vacancies, wages, and employment
# - compare alternative break-even definitions
# - calibrate and then estimate the baseline state-space prototype
# - move the stable version into a fuller IRISpie workflow
